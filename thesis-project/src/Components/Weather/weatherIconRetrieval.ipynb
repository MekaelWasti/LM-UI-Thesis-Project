# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

# %%
df
# Out:
#     code                                       day  \
# 0   1000                                     Sunny
# 1   1003                             Partly cloudy
# 2   1006                                    Cloudy
# 3   1009                                  Overcast
# 4   1030                                      Mist
# 5   1063                      Patchy rain possible
# 6   1066                      Patchy snow possible
# 7   1069                     Patchy sleet possible
# 8   1072          Patchy freezing drizzle possible
# 9   1087               Thundery outbreaks possible
# 10  1114                              Blowing snow
# 11  1117                                  Blizzard
# 12  1135                                       Fog
# 13  1147                              Freezing fog
# 14  1150                      Patchy light drizzle
# 15  1153                             Light drizzle
# 16  1168                          Freezing drizzle
# ...

# %%
df = pd.read_csv("weather_conditions.csv")

condition = "Sunny"
condition = "Blizzard"
# condition = "Clear"

icon = df.loc[(df['day'] == condition) | (df['night'] == condition)]['icon'].values[0]

image = mpimg.imread(f'weatherIcons/64x64/day/{icon}.png')
plt.imshow(image)
